# %%
dias_tupla = ('lunes', 'martes', 'miercoles', 'jueves', 'viernes', 'sabado', 'domingo')
print(type(dias_tupla))
# Out:
# <class 'tuple'>

# %%
Diego = 37
Carmen = 68
Renato = 33
Petita = 'No se dice'
Familia = (Diego, Carmen, Renato, Petita)
print(Familia[3])
# Out:
# No se dice

# %%
primer_diccionario={'primero':'uno', 'segundo':'dos'}
print(type(primer_diccionario))

segundo_diccionario=dict()
segundo_diccionario['primero']='uno'
segundo_diccionario['segundo']='dos'
print(segundo_diccionario)

del segundo_diccionario['primero']
print(segundo_diccionario)
# Out:
# <class 'dict'>
# {'primero': 'uno', 'segundo': 'dos'}
# {'segundo': 'dos'}
